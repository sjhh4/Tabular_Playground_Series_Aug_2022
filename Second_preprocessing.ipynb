# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Duplicate key in file WindowsPath('C:/Users/Hyoungrak Oh/.conda/envs/ETA3.9/lib/site-packages/matplotlib/mpl-data/matplotlibrc'), line 257 ('font.family: sans-serif')
# Duplicate key in file WindowsPath('C:/Users/Hyoungrak Oh/.conda/envs/ETA3.9/lib/site-packages/matplotlib/mpl-data/matplotlibrc'), line 406 ('axes.unicode_minus: True  # use Unicode for the minus symbol rather than hyphen.  See')

# %%
train = pd.read_csv('./data/train.csv')
train
# Out:
#           id product_code  loading attribute_0 attribute_1  attribute_2  \
# 0          0            A    80.10  material_7  material_8            9
# 1          1            A    84.89  material_7  material_8            9
# 2          2            A    82.43  material_7  material_8            9
# 3          3            A   101.07  material_7  material_8            9
# 4          4            A   188.06  material_7  material_8            9
# ...      ...          ...      ...         ...         ...          ...
# 26565  26565            E   158.95  material_7  material_6            6
# 26566  26566            E   146.02  material_7  material_6            6
# 26567  26567            E   115.62  material_7  material_6            6
# 26568  26568            E   106.38  material_7  material_6            6
# 26569  26569            E   131.20  material_7  material_6            6
#
#        attribute_3  measurement_0  measurement_1  measurement_2  ...  \
# ...

# %%
test = pd.read_csv('./data/test.csv')
test
# Out:
#           id product_code  loading attribute_0 attribute_1  attribute_2  \
# 0      26570            F   119.57  material_5  material_6            6
# 1      26571            F   113.51  material_5  material_6            6
# 2      26572            F   112.16  material_5  material_6            6
# 3      26573            F   112.72  material_5  material_6            6
# 4      26574            F   208.00  material_5  material_6            6
# ...      ...          ...      ...         ...         ...          ...
# 20770  47340            I   144.74  material_7  material_5            9
# 20771  47341            I    74.53  material_7  material_5            9
# 20772  47342            I    67.73  material_7  material_5            9
# 20773  47343            I   126.15  material_7  material_5            9
# 20774  47344            I    85.97  material_7  material_5            9
#
#        attribute_3  measurement_0  measurement_1  measurement_2  ...  \
# ...

# %%
train.isnull().sum()
# Out:
# id                   0
# product_code         0
# loading            250
# attribute_0          0
# attribute_1          0
# attribute_2          0
# attribute_3          0
# measurement_0        0
# measurement_1        0
# measurement_2        0
# measurement_3      381
# measurement_4      538
# measurement_5      676
# measurement_6      796
# measurement_7      937
# measurement_8     1048
# measurement_9     1227
# measurement_10    1300
# measurement_11    1468
# measurement_12    1601
# measurement_13    1774
# measurement_14    1874
# measurement_15    2009
# measurement_16    2110
# measurement_17    2284
# failure              0
# dtype: int64

# %%
train_A = train[train['product_code'] == 'A']
train_A
# Out:
#         id product_code  loading attribute_0 attribute_1  attribute_2  \
# 0        0            A    80.10  material_7  material_8            9
# 1        1            A    84.89  material_7  material_8            9
# 2        2            A    82.43  material_7  material_8            9
# 3        3            A   101.07  material_7  material_8            9
# 4        4            A   188.06  material_7  material_8            9
# ...    ...          ...      ...         ...         ...          ...
# 5095  5095            A   120.39  material_7  material_8            9
# 5096  5096            A   123.55  material_7  material_8            9
# 5097  5097            A   119.23  material_7  material_8            9
# 5098  5098            A   111.27  material_7  material_8            9
# 5099  5099            A   194.91  material_7  material_8            9
#
#       attribute_3  measurement_0  measurement_1  measurement_2  ...  \
# ...

# %%
for i in ['A', 'B', 'C', 'D', 'E']:
    globals()['train_{}'.format(i)] = train[train['product_code'] == i]

# %%
display(train_A)
display(train_B)
display(train_C)
display(train_D)
train_E
# Out:
#         id product_code  loading attribute_0 attribute_1  attribute_2  \
# 0        0            A    80.10  material_7  material_8            9
# 1        1            A    84.89  material_7  material_8            9
# 2        2            A    82.43  material_7  material_8            9
# 3        3            A   101.07  material_7  material_8            9
# 4        4            A   188.06  material_7  material_8            9
# ...    ...          ...      ...         ...         ...          ...
# 5095  5095            A   120.39  material_7  material_8            9
# 5096  5096            A   123.55  material_7  material_8            9
# 5097  5097            A   119.23  material_7  material_8            9
# 5098  5098            A   111.27  material_7  material_8            9
# 5099  5099            A   194.91  material_7  material_8            9
#
#       attribute_3  measurement_0  measurement_1  measurement_2  ...  \
# ...

# %%
train_A.isnull().sum()
# Out:
# id                  0
# product_code        0
# loading            49
# attribute_0         0
# attribute_1         0
# attribute_2         0
# attribute_3         0
# measurement_0       0
# measurement_1       0
# measurement_2       0
# measurement_3      68
# measurement_4     102
# measurement_5     151
# measurement_6     175
# measurement_7     176
# measurement_8     187
# measurement_9     225
# measurement_10    257
# measurement_11    296
# measurement_12    326
# measurement_13    330
# measurement_14    316
# measurement_15    377
# measurement_16    388
# measurement_17    426
# failure             0
# dtype: int64

# %%
train_A.describe()
# Out:
#                 id      loading  attribute_2  attribute_3  measurement_0  \
# count  5100.000000  5051.000000       5100.0       5100.0    5100.000000
# mean   2549.500000   127.469361          9.0          5.0      10.325882
# std    1472.387517    39.093590          0.0          0.0       4.230892
# min       0.000000    33.160000          9.0          5.0       0.000000
# 25%    1274.750000    99.820000          9.0          5.0       7.000000
# 50%    2549.500000   121.960000          9.0          5.0      10.000000
# 75%    3824.250000   148.840000          9.0          5.0      13.000000
# max    5099.000000   342.880000          9.0          5.0      26.000000
#
#        measurement_1  measurement_2  measurement_3  measurement_4  \
# count    5100.000000    5100.000000    5032.000000    4998.000000
# mean        4.229412       5.226078      17.808524      11.716103
# std         2.723428       2.884531       0.998438       0.998254
# ...

# %%
train_A_0 = train[(train['product_code'] == 'A') & (train['failure'] == 0)]
train_B_0 = train[(train['product_code'] == 'B') & (train['failure'] == 0)]
train_C_0 = train[(train['product_code'] == 'C') & (train['failure'] == 0)]
train_D_0 = train[(train['product_code'] == 'D') & (train['failure'] == 0)]
train_E_0 = train[(train['product_code'] == 'E') & (train['failure'] == 0)]

# %%
train_A_0.failure.unique()
# Out:
# array([0], dtype=int64)

# %%
train_A_1 = train[(train['product_code'] == 'A') & (train['failure'] == 1)]
train_B_1 = train[(train['product_code'] == 'B') & (train['failure'] == 1)]
train_C_1 = train[(train['product_code'] == 'C') & (train['failure'] == 1)]
train_D_1 = train[(train['product_code'] == 'D') & (train['failure'] == 1)]
train_E_1 = train[(train['product_code'] == 'E') & (train['failure'] == 1)]

# %%
train_A_1.failure.mean()
# Out:
# 1.0

# %%
for i in ['A', 'B', 'C', 'D','E']:
    for j in range(2):
        globals()['train_{}_{}'.format(i, j)] = train[(train['product_code'] == i) & (train['failure'] == j)]

# %%
train_B_1.product_code.unique()
# Out:
# array(['B'], dtype=object)

# %%
train_C_1.failure.unique()
# Out:
# array([1], dtype=int64)

# %%
train_A_1.describe()
# Out:
#                 id      loading  attribute_2  attribute_3  measurement_0  \
# count  1159.000000  1141.000000       1159.0       1159.0    1159.000000
# mean   2534.566868   137.556275          9.0          5.0      10.271786
# std    1459.168433    41.516356          0.0          0.0       4.280270
# min       6.000000    51.300000          9.0          5.0       0.000000
# 25%    1285.000000   107.640000          9.0          5.0       7.000000
# 50%    2569.000000   132.630000          9.0          5.0      10.000000
# 75%    3776.500000   160.720000          9.0          5.0      13.000000
# max    5094.000000   336.360000          9.0          5.0      25.000000
#
#        measurement_1  measurement_2  measurement_3  measurement_4  \
# count    1159.000000    1159.000000    1149.000000     1136.00000
# mean        4.238136       5.263158      17.826853       11.68703
# std         2.722369       2.886862       0.973211        0.99584
# ...

# %%
train_A_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3941 entries, 0 to 5099
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3941 non-null   int64
#  1   product_code    3941 non-null   object
#  2   loading         3910 non-null   float64
#  3   attribute_0     3941 non-null   object
#  4   attribute_1     3941 non-null   object
#  5   attribute_2     3941 non-null   int64
#  6   attribute_3     3941 non-null   int64
#  7   measurement_0   3941 non-null   int64
#  8   measurement_1   3941 non-null   int64
#  9   measurement_2   3941 non-null   int64
#  10  measurement_3   3883 non-null   float64
#  11  measurement_4   3862 non-null   float64
#  12  measurement_5   3830 non-null   float64
#  13  measurement_6   3802 non-null   float64
#  14  measurement_7   3812 non-null   float64
#  15  measurement_8   3791 non-null   float64
#  16  measurement_9   3771 non-null   float64
# ...

# %%
train_A_0.fillna(train_A_0.mean()).mean() == train_A_0.mean()
# Out:
# C:\Users\HYOUNG~1\AppData\Local\Temp/ipykernel_13496/2166954359.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   train_A_0.fillna(train_A_0.mean()).mean() == train_A_0.mean()
# id                 True
# loading           False
# attribute_2        True
# attribute_3        True
# measurement_0      True
# measurement_1      True
# measurement_2      True
# measurement_3     False
# measurement_4     False
# measurement_5     False
# measurement_6     False
# measurement_7     False
# measurement_8     False
# measurement_9     False
# measurement_10    False
# measurement_11    False
# measurement_12    False
# measurement_13    False
# measurement_14    False
# measurement_15    False
# measurement_16    False
# measurement_17    False
# failure            True
# dtype: bool

# %%
train_A_0['loading'].fillna(train_A_0['loading'].mean()).mean() == train_A_0['loading'].mean()
# Out:
# False

# %%
train_A_0['loading'].mean()
# Out:
# 124.52583887468039

# %%
train_A_0['loading'].sum()/len(train_A_0)
# Out:
# 123.5463156559249

# %%
for i in train_A_0.columns.drop(['id', 'product_code', 'attribute_0', 'attribute_1']):
    train_A_0[i] = train_A_0[i].fillna(train_A_0[i].mean())
# Out:
# C:\Users\HYOUNG~1\AppData\Local\Temp/ipykernel_13496/1542974730.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_A_0[i] = train_A_0[i].fillna(train_A_0[i].mean())

# %%
train_A_0.describe()
# Out:
#                 id      loading  attribute_2  attribute_3  measurement_0  \
# count  3941.000000  3941.000000       3941.0       3941.0    3941.000000
# mean   2553.891652   124.525839          9.0          5.0      10.341791
# std    1476.407814    37.710750          0.0          0.0       4.216676
# min       0.000000    33.160000          9.0          5.0       0.000000
# 25%    1270.000000    98.010000          9.0          5.0       7.000000
# 50%    2541.000000   119.280000          9.0          5.0      10.000000
# 75%    3846.000000   144.450000          9.0          5.0      13.000000
# max    5099.000000   342.880000          9.0          5.0      26.000000
#
#        measurement_1  measurement_2  measurement_3  measurement_4  \
# count    3941.000000    3941.000000    3941.000000    3941.000000
# mean        4.226846       5.215174      17.803100      11.724654
# std         2.724079       2.884121       0.998409       0.988866
# ...

# %%
train_A_0.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_A_0["loading"].mean()
# Out:
# 124.52583887468045

# %%
for i in train_A_0.columns.drop(['id', 'product_code', 'attribute_0', 'attribute_1']):
    train_A_1[i] = train_A_1[i].fillna(train_A_1[i].mean())
    train_B_1[i] = train_B_1[i].fillna(train_B_1[i].mean())
    train_C_1[i] = train_C_1[i].fillna(train_C_1[i].mean())
    train_D_1[i] = train_D_1[i].fillna(train_D_1[i].mean())
    train_E_1[i] = train_E_1[i].fillna(train_E_1[i].mean())
    train_E_0[i] = train_E_0[i].fillna(train_E_0[i].mean())
    train_B_0[i] = train_B_0[i].fillna(train_B_0[i].mean())
    train_C_0[i] = train_C_0[i].fillna(train_C_0[i].mean())
    train_D_0[i] = train_D_0[i].fillna(train_D_0[i].mean())
# Out:
# C:\Users\HYOUNG~1\AppData\Local\Temp/ipykernel_13496/3764500567.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_A_1[i] = train_A_1[i].fillna(train_A_1[i].mean())
# C:\Users\HYOUNG~1\AppData\Local\Temp/ipykernel_13496/3764500567.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_B_1[i] = train_B_1[i].fillna(train_B_1[i].mean())
# C:\Users\HYOUNG~1\AppData\Local\Temp/ipykernel_13496/3764500567.py:4: SettingWithCopyWarning:
# ...

# %%
train_A_1.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_B_0.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_B_0.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_B_1.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_C_0.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_C_1.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_D_0.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_D_1.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_E_0.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_E_1.isnull().sum()
# Out:
# id                0
# product_code      0
# loading           0
# attribute_0       0
# attribute_1       0
# attribute_2       0
# attribute_3       0
# measurement_0     0
# measurement_1     0
# measurement_2     0
# measurement_3     0
# measurement_4     0
# measurement_5     0
# measurement_6     0
# measurement_7     0
# measurement_8     0
# measurement_9     0
# measurement_10    0
# measurement_11    0
# measurement_12    0
# measurement_13    0
# measurement_14    0
# measurement_15    0
# measurement_16    0
# measurement_17    0
# failure           0
# dtype: int64

# %%
train_A_1.describe() == train_B_1.describe()
# Out:
#           id  loading  attribute_2  attribute_3  measurement_0  measurement_1  \
# count  False    False        False        False          False          False
# mean   False    False        False        False          False          False
# std    False    False         True         True          False          False
# min    False    False        False        False           True           True
# 25%    False    False        False        False          False          False
# 50%    False    False        False        False          False          False
# 75%    False    False        False        False          False          False
# max    False    False        False        False          False          False
#
#        measurement_2  measurement_3  measurement_4  measurement_5  ...  \
# count          False          False          False          False  ...
# mean           False          False          False          False  ...
# ...

# %%
df = pd.concat([train_A_0, train_A_1, train_B_0, train_B_1, train_C_0, train_C_1, train_D_0, train_D_1, train_E_0, train_E_1])

# %%
df.shape == train.shape
# Out:
# True

# %%
df = df.drop(columns = ['id', 'product_code'])
df
# Out:
#        loading attribute_0 attribute_1  attribute_2  attribute_3  \
# 0        80.10  material_7  material_8            9            5
# 1        84.89  material_7  material_8            9            5
# 2        82.43  material_7  material_8            9            5
# 3       101.07  material_7  material_8            9            5
# 4       188.06  material_7  material_8            9            5
# ...        ...         ...         ...          ...          ...
# 26545   100.26  material_7  material_6            6            9
# 26546   103.60  material_7  material_6            6            9
# 26553   121.42  material_7  material_6            6            9
# 26554   159.43  material_7  material_6            6            9
# 26559   120.73  material_7  material_6            6            9
#
#        measurement_0  measurement_1  measurement_2  measurement_3  \
# 0                  7              8              4         18.040
# ...

# %%
df = pd.get_dummies(data = df, columns = ['attribute_0', 'attribute_1'])

# %%
df
# Out:
#        loading  attribute_2  attribute_3  measurement_0  measurement_1  \
# 0        80.10            9            5              7              8
# 1        84.89            9            5             14              3
# 2        82.43            9            5             12              1
# 3       101.07            9            5             13              2
# 4       188.06            9            5              9              2
# ...        ...          ...          ...            ...            ...
# 26545   100.26            6            9              4             19
# 26546   103.60            6            9              1             15
# 26553   121.42            6            9              1              9
# 26554   159.43            6            9              3             13
# 26559   120.73            6            9              2              9
#
#        measurement_2  measurement_3  measurement_4  measurement_5  \
# ...

# %%
test
# Out:
#           id product_code  loading attribute_0 attribute_1  attribute_2  \
# 0      26570            F   119.57  material_5  material_6            6
# 1      26571            F   113.51  material_5  material_6            6
# 2      26572            F   112.16  material_5  material_6            6
# 3      26573            F   112.72  material_5  material_6            6
# 4      26574            F   208.00  material_5  material_6            6
# ...      ...          ...      ...         ...         ...          ...
# 20770  47340            I   144.74  material_7  material_5            9
# 20771  47341            I    74.53  material_7  material_5            9
# 20772  47342            I    67.73  material_7  material_5            9
# 20773  47343            I   126.15  material_7  material_5            9
# 20774  47344            I    85.97  material_7  material_5            9
#
#        attribute_3  measurement_0  measurement_1  measurement_2  ...  \
# ...

# %%
df_test = test.drop(columns = ['id'])
